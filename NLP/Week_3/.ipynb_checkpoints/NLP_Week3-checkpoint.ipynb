# %% [markdown]
# # Trabajo Semana 3 - NLP
# ### Asignatura: Procesamiento de Lenguaje Natural
# #### Especialización en Inteligencia Artificial
# ##### Realizado por: Michael Andrés Mora Poveda

# %% [markdown]
# ### Objetivo:
#
# El código presentado a continuación tiene como el proceso de tokenización, limpieza y análisis general para el texto de Cien años de Soledad con la librería NLTK. El texto html utilizado se puede encontrar en el link referenciado a continuación:
#
# https://www.culturagenial.com/es/cien-anos-de-soledad-de-gabriel-garcia-marquez/

# %% [markdown]
# #### 1. Obtener texto desde una página web (raspado o scrapping)

# %%
import pandas as pd
import numpy as np
from textblob import TextBlob
import matplotlib.pyplot as plt
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import urllib.request
import requests
from urllib.request import urlopen
from bs4 import BeautifulSoup
from nltk.tokenize import word_tokenize
from nltk.corpus import wordnet
import seaborn as sns

# %% [markdown]
# #### 2. Obtener texto desde una página web (raspado o scrapping)

# %%
# Obtener texto desde url (scrapp o "raspar")
# con urllib se solicita requerimiento al sitio web y, la respuesta (texto) será "leída" por .read
with urllib.request.urlopen('https://www.culturagenial.com/es/cien-anos-de-soledad-de-gabriel-garcia-marquez/') as response:                   
    html = response.read()

# mostrar primeros 400 caracteres del objeto creado mediante response.read
print(html[:400])
# Out:
# b'<!DOCTYPE html>\n<html lang="es">\n<head>\n    <meta charset="utf-8">\n<title>Cien a\xc3\xb1os de soledad, de Garc\xc3\xada M\xc3\xa1rquez: resumen y an\xc3\xa1lisis - Cultura Genial</title>\n\n<meta http-equiv="x-ua-compatible" content="ie=edge">\n<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=2.0, user-scalable=1" />\n\n    <meta name="description" content="Te presentamos el resumen y an\xc3\xa1li'

# %% [markdown]
# #### 3. Crear árbol de objetos Python para el documento HTML

# %%
# crear objeto soup = con BeautifulSoup sobre la entrada (html) creada con response.read
soup = BeautifulSoup(html)

# mostrar contenido del objeto soup creado
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="es">
# <head>
# <meta charset="utf-8"/>
# <title>Cien años de soledad, de García Márquez: resumen y análisis - Cultura Genial</title>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0, user-scalable=1" name="viewport"/>
# <meta content="Te presentamos el resumen y análisis de Cien años de soledad de Gabriel García Márquez, así como el árbol genealógico de la familia Buendía." name="description"/>
# <meta content="Cien años de soledad, de García Márquez: resumen y análisis" property="og:title"/>
# <meta content="Te presentamos el resumen y análisis de Cien años de soledad de Gabriel García Márquez, así como el árbol genealógico de la familia Buendía." property="og:description"/>
# <meta content="https://www.culturagenial.com/es/cien-anos-de-soledad-de-gabriel-garcia-marquez/" property="og:url"/>
# <meta content="article" property="og:type"/>
# <meta content="https://cdn.culturagenial.com/es/imagenes/novela-cien-anos-de-soledad-de-gabriel-garcia-marquez-og.jpg" property="og:image"/>
# <meta content="Cultura Genial" property="og:site_name"/>
# <meta content="154277001819315" property="fb:app_id"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <link href="https://www.culturagenial.com/es/cien-anos-de-soledad-de-gabriel-garcia-marquez/" rel="canonical"/>
# <link href="/es/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/es/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/es/favicon-48x48.png" rel="shortcut icon" sizes="48x48" type="image/png"/>
# <link href="/es/favicon-32x32.png" rel="shortcut icon" sizes="32x32" type="image/png"/>
# <link href="/es/favicon-16x16.png" rel="shortcut icon" sizes="16x16" type="image/png"/>
# <link href="/es/site.webmanifest" rel="manifest"/>
# <link color="#5bbad5" href="/es/safari-pinned-tab.svg" rel="mask-icon"/>
# <meta content="#da532c" name="msapplication-TileColor"/>
# <meta content="#ffffff" name="theme-color"/>
# <link href="/es/manifest.json" rel="manifest"/>
# <link href="https://www.culturagenial.com/es/rss/" rel="alternate" title="RSS" type="application/rss+xml"/>
# <script type="application/ld+json">{"@context":"http://schema.org/","@type":"Article","inLanguage":"es","headline":"Cien a\u00f1os de soledad, de Garc\u00eda M\u00e1rquez: resumen y an\u00e1lisis","description":"Te presentamos el resumen y an\u00e1lisis de Cien a\u00f1os de soledad de Gabriel Garc\u00eda M\u00e1rquez, as\u00ed como el \u00e1rbol geneal\u00f3gico de la familia Buend\u00eda.","datePublished":"2018-10-10T20:45:49+0100","dateModified":"2023-08-24T10:35:09+0100","mainEntityOfPage":{"@type":"WebPage","@id":"https://www.culturagenial.com/es/cien-anos-de-soledad-de-gabriel-garcia-marquez/"},"publisher":{"@type":"Organization","name":"Cultura Genial","logo":{"@type":"ImageObject","url":"https://cdn.culturagenial.com/es/logo-amp.png","width":600,"height":60}},"image":["https://cdn.culturagenial.com/es/imagenes/novela-cien-anos-de-soledad-de-gabriel-garcia-marquez-og.jpg"],"author":{"@type":"Person","name":"Andrea Imaginario","sameAs":"https://www.culturagenial.com/es/autor/andrea-imaginario/","jobTitle":"Especialista en artes, literatura e historia cultural"}}</script>
# <style>@media (min-width:1024px){.menu-mobile,.toggle-menu{display:none;visibility:hidden}}.gpt-footer,.gpt-middle{text-align:center;margin:0 auto 20px}.gpt-middle{padding:10px 0;margin:10px 0}@media (max-width:1023px){.footer{padding-bottom:50px!important}}@media (min-width:1023px){.gpt-footer{width:970px;min-height:90px}}.ad-unit.gpt-category-sidebar-sticky,.ad-unit.gpt-sidebar-sticky{position:-webkit-sticky;position:sticky;top:10px;display:table;width:100%}.ad-unit,.taboola{position:relative;padding:20px 0 10px}.ad-unit>div:first-of-type::before,.taboola>div:first-of-type::before{content:'PUBLICIDADE';font-family:'Helvetica Neue',Helvetica,Arial,sans-serif;font-size:.5625rem;color:#6f7e8a;text-align:center;display:block;height:20px;line-height:20px;position:absolute;left:0;right:0;top:0}.ad-unit--es>div:first-of-type::before,.taboola--es>div:first-of-type::before{content:'PUBLICIDAD'}.ad-unit--ru>div>div:first-of-type,.taboola--ru>div>div:first-of-type{content:'РЕКЛАМА'}.ad-unit--en-us>div>div:first-of-type,.taboola--en-us>div>div:first-of-type{content:'ADVERTISEMENT'}.ad-unit-sticky--footer{padding:0;overflow:hidden}.ad-unit-sticky--footer>div::before{content:none}@font-face{font-family:'Muli';font-style:italic;font-weight:400;src:local("Muli Italic"),local("Muli-Italic"),url(https://cdn.culturagenial.com/es/fonts/muli-italic.woff2) format("woff2"),url(https://cdn.culturagenial.com/es/fonts/muli-italic.woff) format("woff")}@font-face{font-family:'Muli';font-style:normal;font-weight:400;src:local("Muli Regular"),local("Muli-Regular"),url(https://cdn.culturagenial.com/es/fonts/muli-regular.woff2) format("woff2"),url(https://cdn.culturagenial.com/es/fonts/muli-regular.woff) format("woff")}@font-face{font-family:'Muli';font-style:normal;font-weight:700;src:local("Muli Bold"),local("Muli-Bold"),url(https://cdn.culturagenial.com/es/fonts/muli-700.woff2) format("woff2"),url(https://cdn.culturagenial.com/es/fonts/muli-700.woff) format("woff")}@font-face{font-family:'Muli';font-style:italic;font-weight:700;src:local("Muli Bold Italic"),local("Muli-BoldItalic"),url(https://cdn.culturagenial.com/es/fonts/muli-700italic.woff2) format("woff2"),url(https://cdn.culturagenial.com/es/fonts/muli-700italic.woff) format("woff")}@font-face{font-family:'Source Sans Pro';font-style:normal;font-weight:300;src:local("Source Sans Pro Light"),local("SourceSansPro-Light"),url(https://cdn.culturagenial.com/es/fonts/source-sans-pro-300.woff2) format("woff2"),url(https://cdn.culturagenial.com/es/fonts/source-sans-pro-300.woff) format("woff")}@font-face{font-family:'Source Sans Pro';font-style:normal;font-weight:400;src:local("Source Sans Pro"),local("SourceSansPro-Regular"),url(https://cdn.culturagenial.com/es/fonts/source-sans-pro-regular.woff2) format("woff2"),url(https://cdn.culturagenial.com/es/fonts/source-sans-pro-regular.woff) format("woff")}@font-face{font-family:'Source Sans Pro';font-style:italic;font-weight:400;src:local("Source Sans Pro Italic"),local("SourceSansPro-It"),url(https://cdn.culturagenial.com/es/fonts/source-sans-pro-italic.woff2) format("woff2"),url(https://cdn.culturagenial.com/es/fonts/source-sans-pro-italic.woff) format("woff")}@font-face{font-family:'Source Sans Pro';font-style:normal;font-weight:700;src:local("Source Sans Pro Bold"),local("SourceSansPro-Bold"),url(https://cdn.culturagenial.com/es/fonts/source-sans-pro-700.woff2) format("woff2"),url(https://cdn.culturagenial.com/es/fonts/source-sans-pro-700.woff) format("woff")}@font-face{font-family:'Source Sans Pro';font-style:italic;font-weight:700;src:local("Source Sans Pro Bold Italic"),local("SourceSansPro-BoldIt"),url(https://cdn.culturagenial.com/es/fonts/source-sans-pro-700italic.woff2) format("woff2"),url(https://cdn.culturagenial.com/es/fonts/source-sans-pro-700italic.woff) format("woff")}h1,h2,h3,h4{line-height:1.2}.section-title .section-title--inner{font-family:"Muli",Helvetica,Arial,sans-serif;line-height:1.2}.article-card--stack .title,h1,h2,h3,h4,h5{font-fam ...
# <body class="body-article">
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-N6TB46D" style="display:none;visibility:hidden" width="0"></iframe></noscript><header class="header">
# <div class="header--top-bar">
# <div class="container header--container">
# <div class="logo">
# <a href="/es/">
# <img alt="Cultura Genial" height="35" src="https://cdn.culturagenial.com/es/img/logo.png" srcset="https://cdn.culturagenial.com/es/img/logo@2x.png 2x
#                     ,https://cdn.culturagenial.com/es/img/logo@3x.png 3x" width="138"/>
# </a>
# </div>
# <div class="toggle-menu">
# <button class="toggle-menu--button" title="Menú"><i></i></button>
# </div>
# <nav class="nav nav--desktop">
# <div class="main-menu">
# <a href="/es/literatura/">Literatura</a>
# <a href="/es/arquitectura/">Arquitectura</a>
# <a href="/es/pintura/">Pintura</a>
# <a href="/es/cine/">Cine</a>
# <a href="/es/filosofia/">Filosofía</a>
# </div>
# <div class="search-desktop">
# <form action="/es/busca/" role="search">
# <input class="search-desktop--input" name="s" placeholder="Buscar" type="text" value=""/>
# <i></i>
# </form>
# </div>
# </nav>
# </div>
# </div>
# <div class="menu-mobile">
# <div class="container menu-mobile--container">
# <div class="search-mobile">
# <form action="/es/busca/" role="search">
# <input autocomplete="off" class="search-mobile--input" name="s" placeholder="Buscar..." type="text" value=""/>
# <button class="search-mobile--button" title="Buscar"><i></i></button>
# </form>
# </div>
# <div class="cats-mobile">
# <div class="title-list">Categorías</div>
# <nav class="cats-mobile--list">
# <a href="/es/literatura/">Literatura</a>
# <a href="/es/arquitectura/">Arquitectura</a>
# <a href="/es/pintura/">Pintura</a>
# <a href="/es/cine/">Cine</a>
# <a href="/es/filosofia/">Filosofía</a>
# <a href="/es/escultura/">Escultura</a>
# <a href="/es/poesia/">Poesía</a>
# <a href="/es/frases-y-discursos/">Frases y discursos</a>
# <a href="/es/artes-visuales/">Artes visuales</a>
# <a href="/es/musica/">Música</a>
# <a href="/es/series/">Series</a>
# <a href="/es/periodos-y-movimientos/">Periodos y movimientos</a>
# </nav>
# </div>
# </div>
# </div>
# </header>
# <div class="container">
# <ol class="breadcrumbs" id="breadcrumb" itemscope="" itemtype="http://schema.org/BreadcrumbList">
# <li class="item" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <a href="/es/" itemprop="item">
# <span itemprop="name">Cultura Genial</span></a>
# <meta content="1" itemprop="position"/>
# </li>
# <li class="item" itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem">
# <a href="/es/literatura/" itemprop="item">
# <span itemprop="name">Literatura</span></a>
# <meta content="2" itemprop="position"/>
# </li>
# </ol></div>
# <div class="container content-wrap">
# <main class="main-content--artigo">
# <article class="article" data-art-id="143" id="js-article">
# <header class="article--header">
# <h1 class="article--title">Cien años de soledad, de García Márquez: resumen y análisis</h1>
# <br/>
# <div class="author-article author-article--t">
# <div class="author-article--t__photo author-article--t__photo--circle">
# <img alt="Andrea Imaginario" height="36" src="https://cdn.culturagenial.com/es/imagenes/andrea-imaginario_36.jpg" srcset="https://cdn.culturagenial.com/es/imagenes/andrea-imaginario_36.jpg 1x, https://cdn.culturagenial.com/es/imagenes/andrea-imaginario_72.jpg 2x" title="Andrea Imaginario" width="36"/>
# </div>
# <div class="author-article--t__info">
# <div class="author-article--t__info__name">
# <span>Andrea Imaginario</span>
# </div>
# <div class="author-article--t__info__job-title">
#                         Especialista en artes, literatura e historia cultural                    </div>
# </div>
# </div>
# </header>
# <div class="article--body" id="js-article-body">
# <div class="ad-unit ad-unit--es gpt-article-top min-h--280" id="div-gpt-ad-1537282786689-0"></div><p><em>Cien años de soledad </em>se ha convertido en la novela más emblemática de la cultura latinoamericana. Escrita por Gabriel García Márquez, esta obra se inscribió en lo que para unos es realismo mágico y para Alejo Carpentier es "lo real maravilloso".</p>
# <p>En un exhaustivo trabajo de imaginación, Gabriel García Márquez narra la historia de siete generaciones de la familia Buendía, familia condenada a la soledad.</p>
# <h2>Resumen de <em>Cien años de soledad</em>
# </h2><p>La novela está estructurada en capítulos sin nombrar. Sin embargo, para facilitar la comprensión del argumento, hemos ordenado y separado el relato en cuatro etapas que identifican, a grandes rasgos, los pasajes más emblemáticos.</p>
# <figure class="image"><span class="img"><img alt="Aracataca" height="472" src="https://cdn.culturagenial.com/es/imagenes/1200px-aracataca-s-train-station-cke.jpg" width="630"/></span><figcaption>Estación del tren de Aracataca, pueblo donde nació Gabriel García Márquez y que inspiró la novela.</figcaption></figure><p>Desde un recorrido por la memoria de su Aracataca natal, el escritor observa pasar el enfrentamiento decimonónico entre liberales y conservadores, la llegada del tren, el auge de la fiebre del banano, la expansión del capitalismo y sus prácticas de dominación, en fin: el paso de la tradición a la modernidad desde la periferia.</p>
# <div class="ad-unit ad-unit--es gpt-middle" id="div-gpt-ad-1537282915417-0"></div><p>García Márquez también dialoga con los valores de una cultura atravesada por toda suerte de relatos míticos y religiosos, que tienen un gran poder significativo. Le da voz a los prejuicios, a las supersticiones más vivas y fuertes, y a las imágenes bíblicas del catolicismo, naturalizadas en el imaginario popular latinoamericano: un pecado original que espera su castigo, una asunción y un diluvio son apenas algunos de estos símbolos.</p>
# <p>Así, García Márquez va articulando un discurso mítico, un relato de símbolos que explica el origen y el fin de un microcosmos en el que se construye una imagen del mundo, y al mismo tiempo se hila en la red de un tiempo histórico amplio.</p>
# <h3>Los personajes y los arquetipos</h3><p>Los nombres de los personajes en esta novela se repiten de generación a generación, prácticamente idénticos, como si de arquetipos humanos de tratara, imbuidos, como suelen estar estos, en los conflictos más profundos de la cultura. Parecen actuar como personajes míticos que representan conceptos y estructuras de pensamiento que explican la cosa humana, cual personajes griegos.</p>
# <p>Pero García Márquez da un paso más allá cuando otorga nombres similares a cada personaje. Con este hecho, recalca el peso de la herencia, de la memoria, del mandato de los ancestros, el peso de la historia y la cultura.</p>
# <p>Quizá, de algún modo, cada personaje no sea un arquetipo de individuo, sino la expresión de las diversas fuerzas de la historia que empujan en direcciones diferentes.</p>
# <p>Los impulsivos y soñadores Arcadios, los retraídos y curiosos Aurelianos, las enérgicas pero supersticiosas Úrsulas o una Fernanda en extremo religiosa y tiránica, pueden representar, al fin y al cabo, las fuerzas de la historia debatiéndose por predominar (la búsqueda del conocimiento, la fuerza militar, la religión, los prejuicios, el capitalismo), imágenes del mundo negadas a desaparecer, todas entramadas en el gran relato del fundador.</p>
# <h3>El amor y la historia</h3><p>Pero, ¿qué pueden hacer estas fuerzas, estas imágenes, contra el paso del tiempo? ¿Qué pueden, acaso, contra la naturaleza? ¿Qué pueden contra el misterio de los símbolos y de la imaginación? ¿Qué pueden contra el destino humano?</p>
# <p>En cada relato de <em>Cien años de soledad</em>, en la historia de cada personaje y en la forma en que cada una se hila, solo una fuerza permanece amarrada, velada, arrinconada por la energía de las fuerzas contrarias: el <strong>amor</strong>, que cada vez que se asoma, lucha sin éxito para abrirse paso. Esta fuerza humana vital sucumbe ante el peso de una cultura que, en cierto sentido, condena a los Buendía a vivir cien años de soledad.</p>
# <p>Ver también:</p>
# <ul>
# <li>
# <a href="/es/gabriel-garcia-marquez/">Gabriel García Márquez: biografía y libros</a>.</li>
# <li>
# <h2>Primer capítulo de Cien años de soledad leído por Gabriel García Márquez</h2><div data-oembed-url="https://www.youtube.com/watch?v=ZQiWBEUdudo&amp;feature=youtu.be&amp;list=RDvbMGKCH5SrM">
# <div class="sg-oembed" data-oembed-height="344" data-oembed-iframe-src="https://www.youtube.com/embed/ZQiWBEUdudo?feature=oembed" data-oembed-img-placeholder="https://i.ytimg.com/vi/ZQiWBEUdudo/hqdefault.jpg" data-oembed-provider="youtube" data-oembed-type="video" data-oembed-width="459"><a href="https://www.youtube.com/watch?v=ZQiWBEUdudo&amp;feature=youtu.be&amp;list=RDvbMGKCH5SrM" rel="nofollow">Cien años de soledad leído por Gabo</a></div>
# </div><p>Vea también:</p>
# <ul>
# <li><a href="/es/libros-imperdibles-de-gabriel-garcia-marquez/">Libros imperdibles de Gabriel García Márquez</a></li>
# <li><a href="/es/libro-el-coronel-no-tiene-quien-le-escriba-de-gabriel-garcia-marquez/">El coronel no tiene quien le escriba, de Gabriel García Márquez</a></li>
# <li><a href="/es/cronica-de-una-muerte-anunciada-de-gabriel-garcia-marquez/">Crónica de una muerte anunciada, de Gabriel García Márquez</a></li>
# <li><a href="/es/libros-para-leer/">Libros imprescindibles para leer en tu vida</a></li>
# <li><a href="/es/pedro-paramo-de-juan-rulfo/">Pedro Páramo de Juan Rulfo: resumen, personajes y análisis</a></li>
# <li><a href="/es/realismo-magico/">Realismo mágico: qué es, características y autores</a></li>
# <li><a href="/es/los-miserables-de-victor-hugo/">Los miserables de Víctor Hugo: resumen, personajes y análisis</a></li>
# </ul>
# <div>
# <div class="gtx-trans-icon"></div>
# </div><div>
# <div class="gtx-trans-icon"></div>
# </div><div>
# <div class="gtx-trans-icon"></div>
# </div> </div>
# <div class="article-footer">
# <div class="sg-feedback" data-author-id="100" data-author-name="Andrea Imaginario" data-type-id="143" data-type-of="article" data-type-title="Cien años de soledad, de García Márquez: resumen y análisis" data-type-url="cien-anos-de-soledad-de-gabriel-garcia-marquez" id="sg-feedback">
# </div>
# <script async="" src="https://cdn.7gra.us/feedback-css/v2.js"></script>
# <script async="" src="https://cdn.7gra.us/feedback/v2.js"></script>
# <script>
#                         window.onload = function() {
#                             new Feedback({
#                                 environment: "production",
#                                 project_id: 87,
#                                 project_name: "www.culturagenial.com/es",
#                                 author_id:  "100",
#                                 author_name: "Andrea Imaginario",
#                                 content_type: "article",
#                                 content_id:  "143",
#                                 content_url: "cien-anos-de-soledad-de-gabriel-garcia-marquez",
# 								content_title: "Cien años de soledad, de García Márquez: resumen y análisis",
# 								rating_title: {
# 									text: "¿Fue útil este contenido?",
# 								},
# 								rating_option_radio: {
# 									options: [
# 										{
# 											text: "Sí",
# 											improvement_title: "Gracias. ¿Cómo podemos mejorar?",
# 											improvement_comment_placeholder: "Explica aquí",
# 											improvement_options: []
# 										},
# 										{
# 											text: "No",
# 											improvement_title: "¿Cómo podemos mejorar?",
# 											improvement_comment_placeholder: "Explica aquí para que podamos mejorar",
# 											improvement_options: [
# 												"Este contenido contiene información incorrecta",
# 												"Este contenido no tiene la información que busco",
# 												"Otro"
# 											]
# 										}
# 									]
# 								},
# 								message_thanks : {
# 									text : "Gracias. Tu opinión ha sido registrada",
# 								},
#                             });
#                         }
#                     </script>
# <div class="share-module">
# <div class="sg-social-hidden sg-social" data-text-selector-id="js-article-body" data-title="Cien años de soledad, de García Márquez: resumen y análisis" data-url="https://www.culturagenial.com/es/cien-anos-de-soledad-de-gabriel-garcia-marquez/"><div class="sg-facebook-share"><button class="sg-facebook-btn" title="Compartir | Facebook">
# <span class="icon-sg-social icon-sg-social-facebook"></span>
# <span class="text-sg-social">Compartir</span>
# </button></div><div class="sg-twitter-share"><button class="sg-twitter-btn sg-icon-only" title="Tuitear">
# <span class="icon-sg-social icon-sg-social-twitter"></span>
# </button></div><div class="sg-whatsapp-share"><button class="sg-whatsapp-btn sg-icon-only" title="Mandar | WhatsApp">
# <span class="icon-sg-social icon-sg-social-whatsapp"></span>
# </button></div><div class="sg-sms-share"><button class="sg-sms-btn sg-icon-only" title="  | Sms">
# <span class="icon-sg-social icon-sg-social-sms"></span>
# </button></div><div class="sg-email-share"><button class="sg-email-btn sg-icon-only" title="Email">
# <span class="icon-sg-social icon-sg-social-email"></span>
# </button></div><div class="sg-print-share"><button class="sg-print-btn sg-icon-only" title="Impresión">
# <span class="icon-sg-social icon-sg-social-print"></span>
# </button></div></div> </div>
# </div>
# <div class="author-article author-article--b">
# <div class="author-article--b__wrapper">
# <div class="author-article--b__photo author-article--b__photo--circle">
# <img alt="Andrea Imaginario" height="36" src="https://cdn.culturagenial.com/es/imagenes/andrea-imaginario_36.jpg" srcset="https://cdn.culturagenial.com/es/imagenes/andrea-imaginario_36.jpg 1x,https://cdn.culturagenial.com/es/imagenes/andrea-imaginario_72.jpg 2x" title="Andrea Imaginario" width="36"/>
# </div>
# <div class="author-article--b__info">
# <div class="author-article--b__info__reviewer">
# <a href="/es/autor/andrea-imaginario/">Andrea Imaginario</a> </div>
# </div>
# <div class="author-article--b__bio">
#                 Profesora universitaria, cantante, licenciada en Artes (mención Promoción Cultural), con maestría en Literatura Comparada por la Universidad Central de Venezuela, y doctoranda en Historia en la Universidad Autónoma de Lisboa.            </div>
# </div>
# </div>
# </article>
# </main>
# <aside class="sidebar">
# <div class="sidebar-block articles--list">
# <div class="section-title section-title--line-below">
# <h3 class="section-title--inner">Más populares</h3>
# </div>
# <div class="articles">
# <div class="article-card article-card--list article-card--gray">
# <a href="/es/poemas-de-amor-cortos/">
# <span class="article-no-img card-img card-img--5by4">
# <img alt="37 poemas de amor cortos con su autor" height="96" src="https://cdn.culturagenial.com/es/imagenes/poemas-de-amor-cortos-54xs.jpg" width="120"/>
# </span>
# <div class="card-content">
# <span class="title">37 poemas de amor cortos con su autor</span>
# </div>
# </a>
# </div>
# <div class="article-card article-card--list article-card--gray">
# <a href="/es/libro-el-principito/">
# <span class="article-no-img card-img card-img--5by4">
# <img alt="El Principito: análisis y resumen del libro" height="96" src="https://cdn.culturagenial.com/es/imagenes/libro-el-principito-54xs.jpg" width="120"/>
# </span>
# <div class="card-content">
# <span class="title">El Principito: análisis y resumen del libro</span>
# </div>
# </a>
# </div>
# <div class="article-card article-card--list article-card--gray">
# <a href="/es/libro-la-metamorfosis-de-franz-kafka/">
# <span class="article-no-img card-img card-img--5by4">
# <img alt="Libro La metamorfosis de Franz Kafka: resumen y análisis" height="96" src="https://cdn.culturagenial.com/es/imagenes/libro-la-metamorfosis-de-franz-kafka-54xs.jpg" width="120"/>
# </span>
# <div class="card-content">
# <span class="title">Libro La metamorfosis de Franz Kafka: resumen y análisis</span>
# </div>
# </a>
# </div>
# <div class="article-card article-card--list article-card--gray">
# <a href="/es/la-odisea-de-homero/">
# <span class="article-no-img card-img card-img--5by4">
# <img alt="La odisea de Homero: resumen, análisis y personajes de libro" height="96" src="https://cdn.culturagenial.com/es/imagenes/la-odisea-de-homero-54xs.jpg" width="120"/>
# </span>
# <div class="card-content">
# <span class="title">La odisea de Homero: resumen, análisis y personajes de libro</span>
# </div>
# </a>
# </div>
# <div class="article-card article-card--list article-card--gray">
# <a href="/es/edipo-rey/">
# <span class="article-no-img card-img card-img--5by4">
# <img alt="Edipo Rey, de Sófocles: resumen, análisis y personajes de la obra" height="96" src="https://cdn.culturagenial.com/es/imagenes/edipo-rey-54xs.jpg" width="120"/>
# </span>
# <div class="card-content">
# <span class="title">Edipo Rey, de Sófocles: resumen, análisis y personajes de la obra</span>
# </div>
# </a>
# </div>
# <div class="article-card article-card--list article-card--gray">
# <a href="/es/la-iliada/">
# <span class="article-no-img card-img card-img--5by4">
# <img alt="La Ilíada de Homero: resumen y personajes" height="96" src="https://cdn.culturagenial.com/es/imagenes/la-iliada-54xs.jpg" width="120"/>
# </span>
# <div class="card-content">
# <span class="title">La Ilíada de Homero: resumen y personajes</span>
# </div>
# </a>
# </div>
# </div> </div>
# <div class="sidebar-block last-articles">
# <div class="article-card article-card--stack">
# <div class="card-header">
# <h2 class="secondary-title">Más reciente</h2>
# </div>
# <div class="article">
# <a class="title" href="/es/pedro-paramo-de-juan-rulfo/">Pedro Páramo de Juan Rulfo: resumen, personajes y análisis</a>
# </div>
# <div class="article">
# <a class="title" href="/es/mejores-cuentos/">27 cuentos que debes leer una vez en tu vida (explicados)</a>
# </div>
# <div class="article">
# <a class="title" href="/es/cuentos-largos-para-ninos/">9 cuentos largos para cautivar a los niños</a>
# </div>
# <div class="article">
# <a class="title" href="/es/peliculas-de-terror-recientes/">Las 61 mejores películas de terror (clásicas y recientes)</a>
# </div>
# <div class="article">
# <a class="title" href="/es/frankenstein-de-mary-shelley/">Frankenstein de Mary Shelley: resumen y análisis</a>
# </div>
# <div class="article">
# <a class="title" href="/es/mejores-peliculas-de-netflix/">Las 62 mejores películas de Netflix para disfrutar este 2023</a>
# </div>
# <div class="card-footer">
# <a class="btn" href="/es/ultimas-novedades/">Ver más</a>
# </div>
# </div>
# </div><div class="ad-unit ad-unit--es gpt-halfpage gpt-sidebar-sticky" id="div-gpt-sg-6c82efd10be2f91ca022a2bbc06d1260"></div></aside>
# </div>
# <div class="container">
# <div class="related-section">
# <div class="section-title section-title--line-behind">
# <h3 class="section-title--inner">Recomendado</h3>
# </div>
# <div class="articles">
# <div class="article-card article-card--classic">
# <a href="/es/mejores-cuentos/">
# <span class="article-no-img card-img card-img--5by4">
# <img alt="27 cuentos que debes leer una vez en tu vida (explicados)" height="204" src="https://cdn.culturagenial.com/es/imagenes/mejores-cuentos-54s.jpg" width="255"/>
# </span>
# <div class="card-content">
# <span class="title">27 cuentos que debes leer una vez en tu vida (explicados)</span>
# </div>
# </a>
# </div>
# <div class="article-card article-card--classic">
# <a href="/es/mejores-cuentos-latinoamericanos-explicados/">
# <span class="article-no-img card-img card-img--5by4">
# <img alt="Los 20 mejores cuentos latinoamericanos explicados" height="204" src="https://cdn.culturagenial.com/es/imagenes/mejores-cuentos-latinoamericanos-explicados-54s.jpg" width="255"/>
# </span>
# <div class="card-content">
# <span class="title">Los 20 mejores cuentos latinoamericanos explicados</span>
# </div>
# </a>
# </div>
# <div class="article-card article-card--classic">
# <a href="/es/cuentos-de-terror-autores-famosos/">
# <span class="article-no-img card-img card-img--5by4">
# <img alt="11 cuentos de terror de autores famosos" height="204" src="https://cdn.culturagenial.com/es/imagenes/historias-de-terror-54s.jpg" width="255"/>
# </span>
# <div class="card-content">
# <span class="title">11 cuentos de terror de autores famosos</span>
# </div>
# </a>
# </div>
# <div class="article-card article-card--classic">
# <a href="/es/cuentos-de-ciencia-ficcion/">
# <span class="article-no-img card-img card-img--5by4">
# <img alt="9 cuentos de ciencia ficción para adolescentes (comentados)" height="204" src="https://cdn.culturagenial.com/es/imagenes/cuentos-de-ciencia-ficcion-54s.jpg" width="255"/>
# </span>
# <div class="card-content">
# <span class="title">9 cuentos de ciencia ficción para adolescentes (comentados)</span>
# </div>
# </a>
# </div>
# <div class="article-card article-card--classic">
# <a href="/es/peliculas-recomendadas/">
# <span class="article-no-img card-img card-img--5by4">
# <img alt="130 películas recomendadas" height="204" src="https://cdn.culturagenial.com/es/imagenes/peliculas-recomendadas-54s.jpg" width="255"/>
# </span>
# <div class="card-content">
# <span class="title">130 películas recomendadas</span>
# </div>
# </a>
# </div>
# <div class="article-card article-card--classic">
# <a href="/es/cuentos-largos-para-ninos/">
# <span class="article-no-img card-img card-img--5by4">
# <img alt="9 cuentos largos para cautivar a los niños" height="204" src="https://cdn.culturagenial.com/es/imagenes/cuentos-largos-para-ninos-54s.jpg" width="255"/>
# </span>
# <div class="card-content">
# <span class="title">9 cuentos largos para cautivar a los niños</span>
# </div>
# </a>
# </div>
# <div class="article-card article-card--classic">
# <a href="/es/cuentos-de-amor/">
# <span class="article-no-img card-img card-img--5by4">
# <img alt="7 cuentos de amor que te robarán el corazón" height="204" src="https://cdn.culturagenial.com/es/imagenes/cuentos-de-amor-54s.jpg" width="255"/>
# </span>
# <div class="card-content">
# <span class="title">7 cuentos de amor que te robarán el corazón</span>
# </div>
# </a>
# </div>
# <div class="article-card article-card--classic">
# <a href="/es/gabriel-garcia-marquez/">
# <span class="article-no-img card-img card-img--5by4">
# <img alt="Gabriel García Márquez" height="204" src="https://cdn.culturagenial.com/es/imagenes/gabriel-garcia-marquez-biografia-obras-54s.jpg" width="255"/>
# </span>
# <div class="card-content">
# <span class="title">Gabriel García Márquez</span>
# </div>
# </a>
# </div>
# </div>
# </div>
# <div class="taboola taboola--es" id="taboola"></div>
# </div>
# <div class="ad-unit ad-unit--es gpt-footer" id="div-gpt-ad-1537282725859-0"></div>
# <script>
#     (function () {
#         var f = function () {
#             skunkbase.articlehit();
#             skunkbase.articleTable();
#
#         };
# 		        window.addEventListener("load", f, false);
#     })();
# </script>
# <footer class="footer">
# <div class="container">
# <nav class="footer--menu">
# <div><a href="/es/ultimas-novedades/">Últimas Novedades</a></div>
# <div><a href="/es/populares/">Populares</a></div>
# <div><a href="/es/contacto/">Contacto</a></div>
# <div><a href="/es/privacidad/">Privacidad</a></div>
# <div><a href="/es/terminos-de-uso/">Términos de uso</a></div>
# <div><a href="/es/sobre-nosotros/">Sobre nosotros</a></div>
# <div><a href="/es/como-citar/">¿Cómo citar?</a></div>
# <div><a href="/es/rss/">RSS Feed</a></div>
# </nav>
# <div class="footer--copy">2018 - 2023 © <a class="sg" href="https://www.7graus.com/" rel="nofollow co-worker" target="_blank">7Graus</a></div>
# <div class="toggle-menu">
# <button class="toggle-menu--button" title="Menú"><i></i></button>
# </div>
# </div>
# </footer><div style="max-height:50px;width:100%;z-index:2147483647;position:fixed;background:#fff url(https://cdn.7gra.us/gpt/loading.svg) center center/35px no-repeat;left:0;bottom:0px;text-align:center;display:none;box-shadow:0 0 5px 0 rgba(0,0,0,0.2)">
# <div style="position:fixed;width:29px;height:25px;right:0;bottom:50px;background-color:#fff;-webkit-border-radius:0;-moz-border-radius:0;border-radius:0;-webkit-border-top-left-radius:10px;-moz-border-top-left-radius:10px;border-top-left-radius:10px;z-index:1;box-shadow:0 -2px 2px 0 rgba(0,0,0,0.1)">
# <svg height="24" viewbox="0 0 40 40" width="24" x="0" xmlns="http://www.w3.org/2000/svg" y="0"><path d="M 10,10 L 30,30 M 30,10 L 10,30" style="stroke:#4f4f4f;fill:transparent;stroke-width:4;"></path></svg>
# </div>
# <div class="ad-unit-sticky--footer" id="div-gpt-sg-b44e957dda42a577c453f9511f832f13"></div>
# </div><script>(function(){var s0;var s1;var s2;var s3;var s4;var s5;var s6;googletag.cmd.push(function(){googletag.pubads().enableLazyLoad({"fetchMarginPercent":500,"renderMarginPercent":200,"mobileScaling":2});googletag.pubads().disableInitialLoad();googletag.enableServices();var sm0=googletag.sizeMapping().addSize([0,0],[320,50]).addSize([768,0],[]).build(),sm1=googletag.sizeMapping().addSize([0,0],[]).addSize([270,0],[250,250]).addSize([320,0],[[250,250],[300,250]]).build(),sm2=googletag.sizeMapping().addSize([0,0],[]).addSize([300,0],[[300,250],[250,250],[200,200]]).addSize([320,0],[[300,250],[250,250],[200,200]]).addSize([336,0],[[336,280],[300,250],[250,250],[200,200]]).addSize([992,0],[[300,600],[240,400],[160,600],[300,250],[120,600],[250,250],[200,200]]).build(),sm3=googletag.sizeMapping().addSize([0,0],[]).addSize([270,0],[[250,250]]).addSize([320,0],[[300,250],[250,250]]).addSize([356,0],[[336,280],[300,250],[250,250]]).build(),sm4=googletag.sizeMapping().addSize([0,0],[]).addSize([300,0],[[300,250],[250,250],[200,200]]).addSize([320,0],[[300,250],[250,250],[200,200]]).addSize([336,0],[[336,280],[300,250],[250,250],[200,200]]).addSize([470,0],[[336,280],[300,250],[250,250],[200,200]]).addSize([992,0],[[970,90],[728,90],[970,66],[320,100],[300,100],[468,60],[300,75],[320,50],[300,50]]).build();var ss0=[320,50],ss1=[[300,250],[250,250]],ss2=[[336,280],[300,600],[300,250],[250,250],[240,400],[200,200],[160,600],[120,600]],ss3=[[336,280],[300,250],[250,250]],ss4=[[970,90],[970,66],[728,90],[468,60],[336,280],[320,100],[320,50],[300,250],[300,100],[300,75],[300,50],[250,250],[200,200]];s0=googletag.defineSlot('/1062898/culturagenialES_sticky_320x50',ss0,'div-gpt-sg-b44e957dda42a577c453f9511f832f13').defineSizeMapping(sm0).addService(googletag.pubads()),s1=googletag.defineSlot('/1062898/CulturaGenialES_Detalhe_Topo_MREC',ss1,'div-gpt-ad-1537282786689-0').defineSizeMapping(sm1).addService(googletag.pubads()),s2=googletag.defineSlot('/1062898/CULTURAGENIAL_ES_ARTICLE_SIDEBARSTICKY',ss2,'div-gpt-sg-6c82efd10be2f91ca022a2bbc06d1260').defineSizeMapping(sm2).addService(googletag.pubads()),s3=googletag.defineSlot('/1062898/CulturaGenialES_InArticle_MREC1',ss3,'div-gpt-ad-1537282848081-0').defineSizeMapping(sm3).addService(googletag.pubads()),s4=googletag.defineSlot('/1062898/CulturaGenialES_InArticle_MREC2',ss3,'div-gpt-ad-1537282915417-0').defineSizeMapping(sm3).addService(googletag.pubads()),s5=googletag.defineSlot('/1062898/CulturaGenialES_InArticle_MREC3',ss3,'div-gpt-ad-1537282967496-0').defineSizeMapping(sm3).addService(googletag.pubads()),s6=googletag.defineSlot('/1062898/CulturaGenialES_ROS_BOTTOM',ss4,'div-gpt-ad-1537282725859-0').defineSizeMapping(sm4).addService(googletag.pubads());var slots=[s0,s1,s2,s3,s4,s5,s6];function getCookieValueByName(name) {
#                     var match = document.cookie.match(new RegExp("(^| )" + name + "=([^;]+)"));
#                     return match ? match[2] : "";
#                 }var esbs=!0;var sg_gpt_sb= getCookieValueByName('sg_gpt_sb')=== '0';hsbs=function(){this.parentNode.style.display="none";document.body.style.paddingBottom="";dsbs();localStorage.setItem("sg_gpt_sb",0);var d = new Date(); d = new Date(d.getTime() + 1000 * 7200);document.cookie = "sg_gpt_sb=0; SameSite=None; Secure;expires="+ d.toGMTString() + ";";},ssbs=function(e){var a=document.getElementById("div-gpt-sg-b44e957dda42a577c453f9511f832f13").parentNode;a.style.display="";document.body.style.paddingBottom="76px";var cb=document.createElement("div");cb.style.clear="both";document.body.appendChild(cb);a.children[0].addEventListener("click",hsbs)},dsbs=function(){googletag.destroySlots([s0]);for(i=slots.length-1;i>=0;--i)if(slots[i]===s0)slots.splice(i,1)};if(sg_gpt_sb){dsbs();}else{googletag.pubads().addEventListener("slotOnload",function(e){if(e.slot===s0&&!esbs)ssbs()});googletag.pubads().addEventListener("slotRenderEnded",function(e){if(e.slot===s0)esbs=e.isEmpty})}slots.forEach(function(s){googletag.display(s.getSlotElementId())});var arslots=[{"i":"div-gpt-sg-b44e957dda42a577c453f9511f832f13","t":45}];var mc={"div-gpt-sg-6c82efd10be2f91ca022a2bbc06d1260":{"reloadTime":45,"minResolution":0,"adUnitPaths":["\/1062898\/CULTURAGENIAL_ES_ARTICLE_SIDEBARSTICKY_R1","\/1062898\/CULTURAGENIAL_ES_ARTICLE_SIDEBARSTICKY_R2","\/1062898\/CULTURAGENIAL_ES_ARTICLE_SIDEBARSTICKY_R3","\/1062898\/CULTURAGENIAL_ES_ARTICLE_SIDEBARSTICKY_R4","\/1062898\/CULTURAGENIAL_ES_ARTICLE_SIDEBARSTICKY_R5"],"sizeVar":ss2,"sizeMappingVar":sm2}},mcs,nextAdUnitPath,mcslot; var gae=function(e,s){if(!window.localStorage || window.localStorage.getItem("sg_gpt_event")!=="1")return;if(typeof gtag!=="undefined"){gtag("event",e,{event_category:"Sg_GPT",event_label:s.getAdUnitPath(),non_interaction:true})}else if(typeof ga!=="undefined")ga("send","event","Sg_GPT",e,s.getAdUnitPath(),0,{nonInteraction:true})};googletag.pubads().addEventListener("impressionViewable",function(e){arslots.forEach(function(v){if(v.i===e.slot.getSlotElementId())setTimeout(function(){googletag.pubads().refresh([e.slot])},1e3*v.t);});gae("ImpressionViewable",e.slot)});googletag.pubads().addEventListener("slotRenderEnded",function(e){gae("SlotRenderEnded",e.slot)})
#                 function setDelay(e, slotOptDiv){
#                     if(e.slot.getSlotElementId()===slotOptDiv){
#                         const mcs=mc[slotOptDiv] || false;
#                         let nextAdUnitPath=mcs.adUnitPaths[0] || false;
#                         setTimeout(function(){
#                             if(nextAdUnitPath){
#                                 googletag.destroySlots([e.slot]);
#                                 mcslot=googletag.defineSlot(nextAdUnitPath, mcs.sizeVar, slotOptDiv);
#                                 if(mcs.sizeMappingVar){
#                                     mcslot.defineSizeMapping(mcs.sizeMappingVar);
#                                 }
#                                 if(e.slot.getCollapseEmptyDiv()!==null){
#                                     mcslot.setCollapseEmptyDiv(e.slot.getCollapseEmptyDiv());
#                                 }
#                                 mcslot.addService(googletag.pubads());
#                                 googletag.display([mcslot][0]);
#                                 apstag.fetchBids({slots: [mcslot], timeout: 2000},
#                 function(bids) {
#                     googletag.cmd.push(function(){
#                         apstag.setDisplayBids();
#                         googletag.pubads().refresh([mcslot]);
#                     });
#                 });
#                                 mcs.adUnitPaths.splice(mcs.adUnitPaths,1);
#                                 mc[slotOptDiv].adUnitPaths=mcs.adUnitPaths;
#                             }else{
#                                 apstag.fetchBids({slots: [mcslot], timeout: 2000},
#                 function(bids) {
#                     googletag.cmd.push(function(){
#                         apstag.setDisplayBids();
#                         googletag.pubads().refresh([mcslot]);
#                     });
#                 });
#                             }
#                         },1e3*mcs.reloadTime);
#                     }
#                 }
#                 for (let i = 0; i < Object.keys(mc).length; i++) {
#                     const el = Object.keys(mc)[i];
#                     googletag.pubads().addEventListener("impressionViewable",function(e){
#                         const minResolution = Object.values(mc)[i].minResolution || 0;
#                         if(window.innerWidth >= minResolution && el === e.slot.getSlotElementId()){
#                             setDelay(e,el);
#                         }
#                     })
#                 }
#             ;window.Sg_GPT_get_slots=function(){return slots};});googletag.cmd.push(function(){
#             apstag.fetchBids({slots: [s0,s1,s2,s3,s4,s5,s6], timeout: 2000},
#             function(bids) {
#                 googletag.cmd.push(function(){
#                     apstag.setDisplayBids();
#                     googletag.pubads().refresh([s0,s1,s2,s3,s4,s5,s6]);
#                 });
#             });
#             });})()</script><script>!function(){var e=function(){var e=document.getElementById("deferred-styles"),n=document.createElement("div");n.innerHTML=e.textContent,document.body.appendChild(n),e.parentElement.removeChild(e)},n=window.requestAnimationFrame||window.mozRequestAnimationFrame||window.webkitRequestAnimationFrame||window.msRequestAnimationFrame;n?n(function(){window.setTimeout(e,0)}):window.addEventListener("load",e)}();</script>
# <script src="https://cdn.culturagenial.com/es/frontoffice.015.js"></script>
# <script>var bhof_options = {"ct":"Wi\/TNgq7aSVElSw7w0Rsx3v2LqwqOHhURhZVOBw2zAHxdzBQxOvEaRO7vExObRKJ90v\/k2mlug4tcoihq3hYHAlFYjVxJfhZz2Hs2OOmv7SCRkXh7jVf9VVSBv9lCJKzlsNRQQKBgjNuGnpU7p4h4rwGV9GVRYIPHwRl7jpeE3ld7BQUjNKm1OaZ93ulEoNY","iv":"43d4ca67226cefdc4e4faaa58150e20f","s":"a3aecb5c84507665"};</script><script>
# (function(e,b,c){function d(){var a=b.createElement(c);var m=b.getElementsByTagName(c)[0];
# a.async=1;a.src="https://cdn.7gra.us/html5-push-notifications/v1.js";m.parentNode.insertBefore(a,m)}"complete"===b.readyState&&d();
# b.addEventListener("readystatechange",function(f){"complete"===f.target.readyState&&d()})})(window,document,"script");
# document.addEventListener('Sg_Html5PushNotifications', function () {
# Sg_Html5PushNotifications.init({"enabled":true,"domain_token":"2y10yFUhzPdnDEN0WcVvnAYTBOxwdLiAB9qF06eFs2oH2IW5CGC9b2","rule":{"enabled":true,"pages":2,"days":15}});
# }, false);
# </script>
# <script type="module">
# (async () => {
#     if ('loading' in HTMLImageElement.prototype) {
#         const allLazyloadImages = document.querySelectorAll("img[loading][data-src]");
#         allLazyloadImages.forEach(img => {
#             img.src = img.dataset.src;
#         });
#     } else {
#         const lazySizesCdn = await import('https://cdnjs.cloudflare.com/ajax/libs/lazysizes/5.2.2/lazysizes.min.js');
#         lazySizes.init();
#     }
# })();
# </script>
# <script async="" defer="" nomodule="" src="https://cdnjs.cloudflare.com/ajax/libs/lazysizes/5.2.2/lazysizes.min.js"></script>
# <sg-bhof backofficelistclass="" backofficelistcontentsurl="https://www.culturagenial.com/backoffice/" backofficeurl="https://www.culturagenial.com/es/backoffice/articles/edit/{id}/" contentdata='{
#     "tier":"2",
#     "datePublished":"2018-10-10 20:45:49",
#     "dateUpdated":"2023-09-15 20:24:55"
#     }' contentid="143" contenttype="1" contenttypefeedback="article" contenturl="/es/cien-anos-de-soledad-de-gabriel-garcia-marquez/" mode="production" newarch="" projectid="87" projecturl="https://www.culturagenial.com" style="display:none"></sg-bhof></body>
# </html>

# %% [markdown]
# #### 4. Extracción del texto del documento html presente en el objeto soup creado

# %%
# crear archivo string del texto presente en el html obtenido y procesado en soup
# objeto text = de la entrada definida (soup) aplicar función .get_text (strip = True)espacio en blanco . 
text = soup.get_text(strip=True)

# mostrar string de texto creada
text
# Out:
# %% [markdown]
# #### 5. Tokenización

# %%
# objeto "tokens" donde se guardarán los tokens por palabras del texto creado 
# tokens = función word_tokenize de NLTK (entrada "text", lenguaje = español)
nltk.download('punkt')
tokens = word_tokenize(text, language='spanish')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/michaelandr/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# #### 6. Depurar tokens en minúsculas y solo caracteres alfanuméricos

# %%
# sobre el objeto "tokens" = colectar en [minúculas] y solo mantener caracteres alfanuméricos
tokens = [word.lower() for word in tokens if word.isalpha()]

# mostrar contenido de "tokens" luego del procesamiento 
print(tokens)
# Out:
# ['cien', 'años', 'de', 'soledad', 'de', 'garcía', 'márquez', 'resumen', 'y', 'análisis', 'cultura', 'genialliteraturaarquitecturapinturacinefilosofíacategoríasliteraturaarquitecturapinturacinefilosofíaesculturapoesíafrases', 'y', 'discursosartes', 'visualesmúsicaseriesperiodos', 'y', 'movimientoscultura', 'genialliteraturacien', 'años', 'de', 'soledad', 'de', 'garcía', 'márquez', 'resumen', 'y', 'análisisandrea', 'imaginarioespecialista', 'en', 'artes', 'literatura', 'e', 'historia', 'culturalcien', 'años', 'de', 'soledadse', 'ha', 'convertido', 'en', 'la', 'novela', 'más', 'emblemática', 'de', 'la', 'cultura', 'latinoamericana', 'escrita', 'por', 'gabriel', 'garcía', 'márquez', 'esta', 'obra', 'se', 'inscribió', 'en', 'lo', 'que', 'para', 'unos', 'es', 'realismo', 'mágico', 'y', 'para', 'alejo', 'carpentier', 'es', 'lo', 'real', 'maravilloso', 'un', 'exhaustivo', 'trabajo', 'de', 'imaginación', 'gabriel', 'garcía', 'márquez', 'narra', 'la', 'historia', 'de', 'siete', 'generaciones', 'de', 'la', 'familia', 'buendía', 'familia', 'condenada', 'a', 'la', 'decien', 'años', 'de', 'soledadla', 'novela', 'está', 'estructurada', 'en', 'capítulos', 'sin', 'nombrar', 'sin', 'embargo', 'para', 'facilitar', 'la', 'comprensión', 'del', 'argumento', 'hemos', 'ordenado', 'y', 'separado', 'el', 'relato', 'en', 'cuatro', 'etapas', 'que', 'identifican', 'a', 'grandes', 'rasgos', 'los', 'pasajes', 'más', 'etapa', 'fundación', 'y', 'primeros', 'años', 'de', 'macondodesde', 'que', 'úrsula', 'iguarán', 'se', 'casó', 'con', 'su', 'primo', 'josé', 'arcadio', 'buendía', 'teme', 'engendrar', 'un', 'niño', 'con', 'cola', 'de', 'cerdo', 'como', 'consecuencia', 'del', 'parentesco', 'por', 'ello', 'se', 'niega', 'temporalmente', 'a', 'consumar', 'el', 'matrimonio', 'esto', 'es', 'causa', 'de', 'que', 'prudencio', 'aguilar', 'se', 'burle', 'de', 'josé', 'arcadio', 'buendía', 'quien', 'ofendido', 'lo', 'mata', 'en', 'duelo', 'para', 'salvar', 'su', 'honor', 'desde', 'entonces', 'el', 'fantasma', 'de', 'aguilar', 'lo', 'persigue', 'y', 'josé', 'arcadio', 'decide', 'irse', 'del', 'por', 'un', 'sueño', 'durante', 'su', 'travesía', 'en', 'la', 'selva', 'josé', 'arcadio', 'buendía', 'decide', 'quedarse', 'en', 'ese', 'punto', 'del', 'camino', 'y', 'fundar', 'macondo', 'pueblo', 'que', 'crece', 'poco', 'a', 'pueblo', 'recibe', 'con', 'frecuencia', 'las', 'visitas', 'de', 'los', 'gitanos', 'su', 'líder', 'melquíades', 'trae', 'siempre', 'artefactos', 'y', 'objetos', 'que', 'obsesionan', 'a', 'josé', 'arcadio', 'entonces', 'el', 'joven', 'matrimonio', 'ya', 'ha', 'concebido', 'a', 'tres', 'hijos', 'josé', 'arcadio', 'aureliano', 'y', 'amaranta', 'además', 'adoptan', 'a', 'rebeca', 'la', 'hija', 'de', 'unos', 'parientes', 'el', 'incesto', 'es', 'una', 'preocupación', 'constante', 'en', 'úrsula', 'quien', 'con', 'los', 'años', 'observa', 'cómo', 'receba', 'y', 'su', 'hijo', 'josé', 'arcadio', 'se', 'enamoran', 'y', 'se', 'macondo', 'llega', 'la', 'peste', 'del', 'insomnio', 'la', 'cual', 'trae', 'consigo', 'la', 'del', 'olvido', 'un', 'brebaje', 'de', 'melquíades', 'pone', 'fin', 'a', 'la', 'peste', 'el', 'éxito', 'es', 'tal', 'que', 'el', 'gitano', 'se', 'queda', 'a', 'vivir', 'en', 'macondo', 'tiempo', 'en', 'el', 'cual', 'escribe', 'unos', 'pergaminos', 'que', 'solo', 'serán', 'descifrados', 'muchos', 'años', 'patriarca', 'josé', 'arcadio', 'buendía', 'vuelve', 'a', 'encontrarse', 'con', 'el', 'fantasma', 'de', 'aguilar', 'y', 'enloquece', 'la', 'familia', 'entonces', 'lo', 'amarra', 'a', 'un', 'árbol', 'del', 'patio', 'trasero', 'donde', 'morirá', 'de', 'un', 'etapa', 'la', 'guerra', 'civil', 'y', 'el', 'coronel', 'aureliano', 'buendíaal', 'estallar', 'la', 'guerra', 'civil', 'aureliano', 'buendía', 'lucha', 'contra', 'los', 'conservadores', 'comandando', 'un', 'grupo', 'de', 'soldados', 'de', 'macondo', 'nombra', 'a', 'su', 'sobrino', 'arcadio', 'como', 'jefe', 'civil', 'y', 'militar', 'del', 'había', 'sido', 'el', 'fruto', 'de', 'una', 'relación', 'de', 'amantes ...

# %% [markdown]
# #### 7. Hallar frecuencia de los tokens en el texto y visualización:

# %%
# objeto para frecuencia_de_palabras "fp" = aplicar función .FreqDist sobre (entrada "tokens")
fp = nltk.FreqDist(tokens)

# función para mostrar contenido de cada token y su valor de frecuencia en el texto
# para cada token y valor (frecuencia) en fp.items (lista creada por FreqDist previamente)
for key,val in fp.items():
    # mostrar key (contenido de token) + separador ":" + valor frecuencia
    print (str(key) + ':' + str(val))
# Out:
# cien:5
# años:21
# de:171
# soledad:8
# garcía:19
# márquez:13
# resumen:11
# y:78
# análisis:4
# cultura:5
# genialliteraturaarquitecturapinturacinefilosofíacategoríasliteraturaarquitecturapinturacinefilosofíaesculturapoesíafrases:1
# discursosartes:1
# visualesmúsicaseriesperiodos:1
cumulative=False)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# #### 8. Remover del texto las Stopwords

# %%
# Crear función que depure el texto de stopwords 
# Objeto "clean_tokens" será creado a partir de una lista del objeto "tokens"
clean_tokens = tokens[:]
# para cada token en "tokens"
for token in tokens:
    # si token está en el diccionario de stopwords en español de NLTK
    if token in stopwords.words('spanish') :
        # entonces remover token de la lista
        clean_tokens.remove(token)
        
# Mostrar objeto "clean_tokens"
print(clean_tokens)
# Out:
# ['cien', 'años', 'soledad', 'garcía', 'márquez', 'resumen', 'análisis', 'cultura', 'genialliteraturaarquitecturapinturacinefilosofíacategoríasliteraturaarquitecturapinturacinefilosofíaesculturapoesíafrases', 'discursosartes', 'visualesmúsicaseriesperiodos', 'movimientoscultura', 'genialliteraturacien', 'años', 'soledad', 'garcía', 'márquez', 'resumen', 'análisisandrea', 'imaginarioespecialista', 'artes', 'literatura', 'historia', 'culturalcien', 'años', 'soledadse', 'convertido', 'novela', 'emblemática', 'cultura', 'latinoamericana', 'escrita', 'gabriel', 'garcía', 'márquez', 'obra', 'inscribió', 'realismo', 'mágico', 'alejo', 'carpentier', 'real', 'maravilloso', 'exhaustivo', 'trabajo', 'imaginación', 'gabriel', 'garcía', 'márquez', 'narra', 'historia', 'siete', 'generaciones', 'familia', 'buendía', 'familia', 'condenada', 'decien', 'años', 'soledadla', 'novela', 'estructurada', 'capítulos', 'nombrar', 'embargo', 'facilitar', 'comprensión', 'argumento', 'ordenado', 'separado', 'relato', 'cuatro', 'etapas', 'identifican', 'grandes', 'rasgos', 'pasajes', 'etapa', 'fundación', 'primeros', 'años', 'macondodesde', 'úrsula', 'iguarán', 'casó', 'primo', 'josé', 'arcadio', 'buendía', 'teme', 'engendrar', 'niño', 'cola', 'cerdo', 'consecuencia', 'parentesco', 'ello', 'niega', 'temporalmente', 'consumar', 'matrimonio', 'causa', 'prudencio', 'aguilar', 'burle', 'josé', 'arcadio', 'buendía', 'ofendido', 'mata', 'duelo', 'salvar', 'honor', 'entonces', 'fantasma', 'aguilar', 'persigue', 'josé', 'arcadio', 'decide', 'irse', 'sueño', 'travesía', 'selva', 'josé', 'arcadio', 'buendía', 'decide', 'quedarse', 'punto', 'camino', 'fundar', 'macondo', 'pueblo', 'crece', 'pueblo', 'recibe', 'frecuencia', 'visitas', 'gitanos', 'líder', 'melquíades', 'trae', 'siempre', 'artefactos', 'objetos', 'obsesionan', 'josé', 'arcadio', 'entonces', 'joven', 'matrimonio', 'concebido', 'tres', 'hijos', 'josé', 'arcadio', 'aureliano', 'amaranta', 'además', 'adoptan', 'rebeca', 'hija', 'parientes', 'incesto', 'preocupación', 'constante', 'úrsula', 'años', 'observa', 'cómo', 'receba', 'hijo', 'josé', 'arcadio', 'enamoran', 'macondo', 'llega', 'peste', 'insomnio', 'trae', 'consigo', 'olvido', 'brebaje', 'melquíades', 'pone', 'fin', 'peste', 'éxito', 'tal', 'gitano', 'queda', 'vivir', 'macondo', 'tiempo', 'escribe', 'pergaminos', 'solo', 'descifrados', 'años', 'patriarca', 'josé', 'arcadio', 'buendía', 'vuelve', 'encontrarse', 'fantasma', 'aguilar', 'enloquece', 'familia', 'entonces', 'amarra', 'árbol', 'patio', 'trasero', 'morirá', 'etapa', 'guerra', 'civil', 'coronel', 'aureliano', 'buendíaal', 'estallar', 'guerra', 'civil', 'aureliano', 'buendía', 'lucha', 'conservadores', 'comandando', 'grupo', 'soldados', 'macondo', 'nombra', 'sobrino', 'arcadio', 'jefe', 'civil', 'militar', 'sido', 'fruto', 'relación', 'amantes', 'josé', 'arcado', 'hijo', 'pilar', 'ternera', 'regente', 'prostíbulo', 'criado', 'casa', 'abuelos', 'condición', 'ocultara', 'origen', 'creció', 'pensando', 'ser', 'hijo', 'gran', 'patriarca', 'nombrado', 'jefe', 'macondo', 'arcadio', 'vuelve', 'dictador', 'tiraniza', 'pueblo', 'muere', 'fusilado', 'actividad', 'líder', 'liberales', 'coronel', 'aureliano', 'buendía', 'enfrenta', 'total', 'batallas', 'cuales', 'sale', 'siempre', 'perdedor', 'cansado', 'pronto', 'coronel', 'comprende', 'lucha', 'armada', 'tiempo', 'aureliano', 'firma', 'tratado', 'paz', 'tras', 'intenta', 'suicidarse', 'regresa', 'macondo', 'pasará', 'resto', 'vida', 'haciendo', 'rehaciendo', 'pescaditos', 'cabras', 'ilustración', 'coronel', 'aureliano', 'buendía', 'retiro', 'militar', 'haciendo', 'rehaciendo', 'pescaditos', 'etapa', 'fiebre', 'bananeraaureliano', 'concibe', 'hijos', 'madres', 'diferentes', 'llamado', 'aureliano', 'triste', 'promueve', 'tren', 'macondo', 'activa', 'comercio', 'permite', 'llegada', 'inventos', 'telégrafo', 'cine', 'atrae', 'inversión', 'grupo', 'extranjero', 'plantación', 'plantación', 'genera', 'ilusión', 'prosperidad', 'pueblo', 'huelga', 'trabajadores',  ...

# %% [markdown]
# #### 7. Hallar frecuencia de los tokens en el texto y visualización sin stopwords:

# %%
# objeto "freq_clean" = función .FreqDist sobre la entrada ("clean_tokens") 
freq_clean = nltk.FreqDist(clean_tokens)
# mostrar contenido del token separado por ":" y seguido por su valor (frecuencia)
for key,val in freq_clean.items() :
    print(str(key) + ':' + str(val))
# Out:
# cien:5
# años:21
# soledad:8
# garcía:19
# márquez:13
# resumen:11
# análisis:4
# cultura:5
# genialliteraturaarquitecturapinturacinefilosofíacategoríasliteraturaarquitecturapinturacinefilosofíaesculturapoesíafrases:1
# discursosartes:1
# visualesmúsicaseriesperiodos:1
# movimientoscultura:1
# genialliteraturacien:1
# análisisandrea:1
# imaginarioespecialista:1
# artes:2
# literatura:4
# historia:11
# culturalcien:1
# soledadse:1
# convertido:1
# novela:5
# emblemática:1
# latinoamericana:1
# escrita:1
# gabriel:10
# obra:3
# inscribió:1
# realismo:2
# mágico:3
# alejo:2
# carpentier:3
# real:4
# maravilloso:4
# exhaustivo:1
# trabajo:1
# imaginación:2
# narra:1
# siete:1
# generaciones:1
# familia:6
# buendía:11
# condenada:1
# decien:3
# soledadla:1
# estructurada:1
# capítulos:1
# nombrar:1
# embargo:1
# facilitar:1
# comprensión:1
# argumento:1
# ordenado:1
# márquezcrónica:1
# anunciada:1
# márquezlibros:1
# imprescindibles:1
# leer:3
# vidapedro:1
# páramo:2
# juan:2
# rulfo:2
# análisisrealismo:1
# características:1
# autoreslos:1
# miserables:1
# víctor:1
# hugo:1
# análisiscompartirandrea:1
# imaginarioprofesora:1
# universitaria:1
# cantante:1
# licenciada:1
# mención:1
# promoción:1
# maestría:1
# comparada:1
# central:1
# doctoranda:1
# autónoma:1
# poemas:1
# cortos:1
# autorel:1
# principito:1
# librolibro:1
# metamorfosis:1
# franz:1
# kafka:1
# análisisla:1
# odisea:1
# homero:2
# libroedipo:1
# rey:1
# sófocles:1
# obrala:1
# ilíada:1
# personajesmás:1
# recientepedro:1
# debes:2
# explicados:2
# cautivar:2
# niñoslas:1
# películas:3
# terror:2
# clásicas:1
# recientes:1
# frankenstein:1
# mary:1
# shelley:1
# análisislas:1
# netflix:1
# disfrutar:1
# latinoamericanos:1
# autores:1
# ciencia:1
# ficción:1
# adolescentes:1
# comentados:1
# robarán:1
# corazóngabriel:1
# márquezúltimas:1
# novedadespopularescontactoprivacidadtérminos:1
# usosobre:1
# citar:1
# rss:1

# %%
# con SeaBorn se configura argumentos del plot
sns.set()

# Establecer tamaño del plot en unidades de pulgadas (ancho, alto)
plt.figure(figsize=[8,2])

# crear plot del objeto "freq_clean" (30 primeros tokens lista de frecuencia, no acumular valores) 
freq_clean.plot(30, cumulative=False)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# #### 9. Sinónimos: Definir lista de sinónimos desde wordnet

# %%
# Establecer lista de sinónimos de wordnet "esp" como diccionario para reemplazar sinónimos en texto
nltk.download('omw-1.4')
synonyms = []
for syn in wordnet.synsets('spa') :
    for lemma in syn.lemmas('spa') :
        synonyms.append(lemma.name())

# mostrar ejemplo de sinónimos
synonyms
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/michaelandr/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# ['abrevadero',
#  'balneario',
#  'spa',
#  'balneario',
#  'complejo_hotelero',
#  'gimnasio',
#  'spa']

# %% [markdown]
# #### 10.  Crear función para reemplazar una palabra token con su sinónimo de wordnet

# %%
for ind,sin in enumerate(synonyms) :
     clean_tokens_sin = [word.replace(synonyms[ind],'independencia') for word in clean_tokens]
        
print(clean_tokens_sin)
# Out:
# ['cien', 'años', 'soledad', 'garcía', 'márquez', 'resumen', 'análisis', 'cultura', 'genialliteraturaarquitecturapinturacinefilosofíacategoríasliteraturaarquitecturapinturacinefilosofíaesculturapoesíafrases', 'discursosartes', 'visualesmúsicaseriesperiodos', 'movimientoscultura', 'genialliteraturacien', 'años', 'soledad', 'garcía', 'márquez', 'resumen', 'análisisandrea', 'imaginarioespecialista', 'artes', 'literatura', 'historia', 'culturalcien', 'años', 'soledadse', 'convertido', 'novela', 'emblemática', 'cultura', 'latinoamericana', 'escrita', 'gabriel', 'garcía', 'márquez', 'obra', 'inscribió', 'realismo', 'mágico', 'alejo', 'carpentier', 'real', 'maravilloso', 'exhaustivo', 'trabajo', 'imaginación', 'gabriel', 'garcía', 'márquez', 'narra', 'historia', 'siete', 'generaciones', 'familia', 'buendía', 'familia', 'condenada', 'decien', 'años', 'soledadla', 'nov
ía', 'retiro', 'militar', 'haciendo', 'rehaciendo', 'pescaditos', 'etapa', 'fiebre', 'bananeraaureliano', 'concibe', 'hijos', 'madres', 'diferentes', 'llamado', 'aureliano', 'triste', 'promueve', 'tren', 'macondo', 'activa', 'comercio', 'permite', 'llegada', 'inventos', 'telégrafo', 'cine', 'atrae', 'inversión', 'grupo', 'extranjero', 'plantación', 'plantación', 'genera', 'ilusión', 'prosperidad', 'pueblo', 'huelga', 'trabajadores',  ...

# %%
freq_clean_sin = nltk.FreqDist(clean_tokens_sin)
for key,val in freq_clean_sin.items() :
    print(str(key) + ':' + str(val))
# Out:
# cien:5
# años:21
# soledad:8
# garcía:19
# márquez:13
# resumen:11
# análisis:4
# cultura:5
# genialliteraturaarquitecturapinturacinefilosofíacategoríasliteraturaarquitecturapinturacinefilosofíaesculturapoesíafrases:1
# discursosartes:1
# visualesmúsicaseriesperiodos:1
# movimientoscultura:1
# genialliteraturacien:1
# análisisandrea:1
# imaginarioespecialista:1
# artes:2
# literatura:4
# historia:11
# culturalcien:1
# soledadse:1
# convertido:1
# novela:5
# emblemática:1
# latinoamericana:1
# escrita:1
# gabriel:10
# obra:3
# inscribió:1
# realismo:2
# mágico:3
# alejo:2
# carpentier:3
# real:4
# maravilloso:4
# exhaustivo:1
# trabajo:1
# imaginación:2
# narra:1
# siete:1
# generaciones:1
# familia:6
# buendía:11
# condenada:1
# decien:3
# soledadla:1
# estructurada:1
# capítulos:1
# nombrar:1
# embargo:1
# facilitar:1
# comprensión:1
# argumento:1
# ordenado:1
# separado:1
# relato:5
# cuatro:1
# etapas:1
# identifican:1
# grandes:1
# rasgos:1
# pasajes:1
# etapa:4
# fundación:1
# primeros:1
# macondodesde:1
# úrsula:5
# iguarán:1
# casó:1
# primo:1
# josé:10
# arcadio:10
# teme:1
# engendrar:1
# niño:4
# cola:2
# cerdo:2
# consecuencia:1
# parentesco:2
# ello:1
# niega:1
# temporalmente:1
# consumar:1
# matrimonio:2
# causa:2
# prudencio:1
# aguilar:3
# burle:1
# ofendido:1
# mata:1
# duelo:1
# salvar:1
# honor:1
# entonces:4
# fantasma:2
# persigue:1
# decide:2
# irse:1
# sueño:1
# travesía:1
# selva:1
# quedarse:1
# punto:1
# camino:2
# fundar:1
# macondo:9
# pueblo:9
# crece:1
# recibe:1
# frecuencia:1
# visitas:1
# gitanos:1
# líder:2
# melquíades:3
# trae:2
# siempre:4
# artefactos:1
# objetos:1
# obsesionan:1
# joven:1
# concebido:1
# tres:1
# hijos:2
# aureliano:12
# amaranta:2
# además:1
# adoptan:1
# rebeca:1
# hija:1
# parientes:1
# incesto:1
# preocupación:1
# constante:1
# observa:2
# cómo:1
# receba:1
# hijo:4
# enamoran:2
# llega:1
# peste:2
# insomnio:1
# consigo:1
# olvido:3
# brebaje:1
# pone:1
# fin:6
# éxito:3
# tal:1
# gitano:1
# queda:3
# vivir:2
# tiempo:7
# escribe:1
# pergaminos:3
# solo:3
# descifrados:1
# patriarca:2
# vuelve:3
# encontrarse:1
